# %%
import pandas as pd

# %%
elections = pd.read_csv('countypres_2000-2020.csv')
elections
# Out:
#        year    state state_po county_name  county_fips        office  \
# 0      2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 1      2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 2      2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 3      2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 4      2000  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
# ...     ...      ...      ...         ...          ...           ...
# 72612  2020  WYOMING       WY    WASHAKIE      56043.0  US PRESIDENT
# 72613  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 72614  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 72615  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 72616  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
#
#                candidate        party  candidatevotes  totalvotes   version  \
# 0                AL GORE     DEMOCRAT            4942       17208  20220315
# 1         GEORGE W. BUSH   REPUBLICAN           11993       17208  20220315
# 2            RALPH NADER        GREEN             160       17208  20220315
# 3                  OTHER        OTHER             113       17208  20220315
# 4                AL GORE     DEMOCRAT           13997       56480  20220315
# ...                  ...          ...             ...         ...       ...
# 72612     DONALD J TRUMP   REPUBLICAN            3245        4032  20220315
# 72613  JOSEPH R BIDEN JR     DEMOCRAT             360        3560  20220315
# 72614       JO JORGENSEN  LIBERTARIAN              46        3560  20220315
# 72615              OTHER        OTHER              47        3560  20220315
# 72616     DONALD J TRUMP   REPUBLICAN            3107        3560  20220315
#
#         mode
# 0      TOTAL
# 1      TOTAL
# 2      TOTAL
# 3      TOTAL
# 4      TOTAL
# ...      ...
# 72612  TOTAL
# 72613  TOTAL
# 72614  TOTAL
# 72615  TOTAL
# 72616  TOTAL
#
# [72617 rows x 12 columns]

# %%
# Combine 'County' and 'State' columns
#elections['county_name'] = elections['county_name'] + ', ' + elections['state']

#elections.drop('state', axis=1, inplace=True)
elections.drop('state_po', axis=1, inplace=True)
elections.drop('county_fips', axis=1, inplace=True)
elections.drop('office', axis=1, inplace=True)
elections.drop('version', axis=1, inplace=True)
elections.drop('mode', axis=1, inplace=True)
elections.drop('candidate', axis=1, inplace=True)

# Result
elections
# Out:
#        year    state county_name        party  candidatevotes  totalvotes
# 0      2000  ALABAMA     AUTAUGA     DEMOCRAT            4942       17208
# 1      2000  ALABAMA     AUTAUGA   REPUBLICAN           11993       17208
# 2      2000  ALABAMA     AUTAUGA        GREEN             160       17208
# 3      2000  ALABAMA     AUTAUGA        OTHER             113       17208
# 4      2000  ALABAMA     BALDWIN     DEMOCRAT           13997       56480
# ...     ...      ...         ...          ...             ...         ...
# 72612  2020  WYOMING    WASHAKIE   REPUBLICAN            3245        4032
# 72613  2020  WYOMING      WESTON     DEMOCRAT             360        3560
# 72614  2020  WYOMING      WESTON  LIBERTARIAN              46        3560
# 72615  2020  WYOMING      WESTON        OTHER              47        3560
# 72616  2020  WYOMING      WESTON   REPUBLICAN            3107        3560
#
# [72617 rows x 6 columns]

# %%
elections = elections.rename(columns={'year': 'Year'})
elections = elections.rename(columns={'state': 'State'})
elections = elections.rename(columns={'county_name': 'County'})
elections = elections.rename(columns={'state': 'State'})
elections = elections.rename(columns={'party': 'Party'})
elections = elections.rename(columns={'candidatevotes': 'Votes'})
elections = elections.rename(columns={'totalvotes': 'Total'})

elections
# Out:
#        Year    State    County        Party  Votes  Total
# 0      2000  ALABAMA   AUTAUGA     DEMOCRAT   4942  17208
# 1      2000  ALABAMA   AUTAUGA   REPUBLICAN  11993  17208
# 2      2000  ALABAMA   AUTAUGA        GREEN    160  17208
# 3      2000  ALABAMA   AUTAUGA        OTHER    113  17208
# 4      2000  ALABAMA   BALDWIN     DEMOCRAT  13997  56480
# ...     ...      ...       ...          ...    ...    ...
# 72612  2020  WYOMING  WASHAKIE   REPUBLICAN   3245   4032
# 72613  2020  WYOMING    WESTON     DEMOCRAT    360   3560
# 72614  2020  WYOMING    WESTON  LIBERTARIAN     46   3560
# 72615  2020  WYOMING    WESTON        OTHER     47   3560
# 72616  2020  WYOMING    WESTON   REPUBLICAN   3107   3560
#
# [72617 rows x 6 columns]

# %%
def clean_text(text):
    if isinstance(text, str):
        return text.title()  # Capitalizes the first letter of each word and makes the rest lowercase
    return text  # Return text unchanged if it's not a string

# Apply this function to a specific column in your dataframe
elections['County'] = elections['County'].apply(clean_text)
elections['Party'] = elections['Party'].apply(clean_text)
elections['State'] = elections['State'].apply(clean_text)

# %%
elections
# Out:
#        Year    State    County        Party  Votes  Total
# 0      2000  Alabama   Autauga     Democrat   4942  17208
# 1      2000  Alabama   Autauga   Republican  11993  17208
# 2      2000  Alabama   Autauga        Green    160  17208
# 3      2000  Alabama   Autauga        Other    113  17208
# 4      2000  Alabama   Baldwin     Democrat  13997  56480
# ...     ...      ...       ...          ...    ...    ...
# 72612  2020  Wyoming  Washakie   Republican   3245   4032
# 72613  2020  Wyoming    Weston     Democrat    360   3560
# 72614  2020  Wyoming    Weston  Libertarian     46   3560
# 72615  2020  Wyoming    Weston        Other     47   3560
# 72616  2020  Wyoming    Weston   Republican   3107   3560
#
# [72617 rows x 6 columns]

# %% [markdown]
# We have no choice but to drop Alaska.

# %%
# Method 1: Using boolean indexing with .str.contains()
elections = elections[~elections['State'].str.contains('Alaska', na=False)]

# %%
elections['Party'].value_counts()
# Out:
# Party
# Democrat       20660
# Republican     20660
# Other          19569
# Green           5953
# Libertarian     4914
# Name: count, dtype: int64

# %%
elections['Percentage'] = round((elections['Votes'] / elections['Total'] * 100), 2)
elections
# Out:
# /var/folders/cf/4zrkk0lx1nbdx9tpklpk4jc00000gn/T/ipykernel_38625/3329014358.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elections['Percentage'] = round((elections['Votes'] / elections['Total'] * 100), 2)
#        Year    State    County        Party  Votes  Total  Percentage
# 0      2000  Alabama   Autauga     Democrat   4942  17208       28.72
# 1      2000  Alabama   Autauga   Republican  11993  17208       69.69
# 2      2000  Alabama   Autauga        Green    160  17208        0.93
# 3      2000  Alabama   Autauga        Other    113  17208        0.66
# 4      2000  Alabama   Baldwin     Democrat  13997  56480       24.78
# ...     ...      ...       ...          ...    ...    ...         ...
# 72612  2020  Wyoming  Washakie   Republican   3245   4032       80.48
# 72613  2020  Wyoming    Weston     Democrat    360   3560       10.11
# 72614  2020  Wyoming    Weston  Libertarian     46   3560        1.29
# 72615  2020  Wyoming    Weston        Other     47   3560        1.32
# 72616  2020  Wyoming    Weston   Republican   3107   3560       87.28
#
# [71756 rows x 7 columns]

# %%
elections = elections[['Year', 'State', 'County', 'Party', 'Votes', 'Percentage', 'Total']]
elections
# Out:
#        Year    State    County        Party  Votes  Percentage  Total
# 0      2000  Alabama   Autauga     Democrat   4942       28.72  17208
# 1      2000  Alabama   Autauga   Republican  11993       69.69  17208
# 2      2000  Alabama   Autauga        Green    160        0.93  17208
# 3      2000  Alabama   Autauga        Other    113        0.66  17208
# 4      2000  Alabama   Baldwin     Democrat  13997       24.78  56480
# ...     ...      ...       ...          ...    ...         ...    ...
# 72612  2020  Wyoming  Washakie   Republican   3245       80.48   4032
# 72613  2020  Wyoming    Weston     Democrat    360       10.11   3560
# 72614  2020  Wyoming    Weston  Libertarian     46        1.29   3560
# 72615  2020  Wyoming    Weston        Other     47        1.32   3560
# 72616  2020  Wyoming    Weston   Republican   3107       87.28   3560
#
# [71756 rows x 7 columns]

# %%
# Pivot the DataFrame for vote totals by year and county for each party
vote_totals = elections.pivot_table(index=['Year', 'State', 'County'], columns='Party', values='Votes', aggfunc='sum')

# Pivot the DataFrame for percentages by year and county for each party
percentage_totals = elections.pivot_table(index=['Year', 'State', 'County'], columns='Party', values='Percentage', aggfunc='sum')

# Merge the two DataFrames together: vote totals and percentages
election_pivot = pd.concat([vote_totals, percentage_totals], axis=1, keys=['Votes', 'Percentage'])

# Flatten the MultiIndex columns and rename them according to the required format
election_pivot.columns = [f'{party} {stat}' for stat, party in election_pivot.columns]

# Reorder columns to keep the parties together (Democratic, Republican, etc.)
party_order = ['Democrat', 'Republican', 'Libertarian', 'Green', 'Other']  # You can add or adjust parties as needed
ordered_columns = []

for party in party_order:
    if f'{party} Votes' in election_pivot.columns:
        ordered_columns.append(f'{party} Votes')
    if f'{party} Percentage' in election_pivot.columns:
        ordered_columns.append(f'{party} Percentage')

# Reindex the DataFrame to match the desired column order
election_pivot = election_pivot[ordered_columns]

# Include the 'Total' column in the final DataFrame
election_results_totals = elections[['Year', 'State', 'County', 'Total']].drop_duplicates()

# Merge the 'Total' column back into the pivoted DataFrame
election_pivot = pd.merge(election_results_totals, election_pivot, on=['Year', 'State', 'County'])

# Move the 'Total' column to the end
election_pivot = election_pivot[[col for col in election_pivot.columns if col != 'Total'] + ['Total']]

# Fill nulls with 0
election_pivot.fillna(0, inplace=True)

# Display the pivoted DataFrame with the correct column ordering and Total column at the end
election_pivot
# Out:
#        Year    State      County  Democrat Votes  Democrat Percentage  \
# 0      2000  Alabama     Autauga          4942.0                28.72
# 1      2000  Alabama     Baldwin         13997.0                24.78
# 2      2000  Alabama     Barbour          5188.0                49.91
# 3      2000  Alabama        Bibb          2710.0                38.16
# 4      2000  Alabama      Blount          4977.0                27.69
# ...     ...      ...         ...             ...                  ...
# 18693  2020  Wyoming  Sweetwater          3823.0                22.89
# 18694  2020  Wyoming       Teton          9848.0                66.60
# 18695  2020  Wyoming       Uinta          1591.0                16.82
# 18696  2020  Wyoming    Washakie           651.0                16.15
# 18697  2020  Wyoming      Weston           360.0                10.11
#
#        Republican Votes  Republican Percentage  Libertarian Votes  \
# 0               11993.0                  69.69                0.0
# 1               40872.0                  72.37                0.0
# 2                5096.0                  49.02                0.0
# 3                4273.0                  60.17                0.0
# 4               12667.0                  70.48                0.0
# ...                 ...                    ...                ...
# 18693           12229.0                  73.24              350.0
# 18694            4341.0                  29.36              255.0
# 18695            7496.0                  79.25              172.0
# 18696            3245.0                  80.48               65.0
# 18697            3107.0                  87.28               46.0
#
#        Libertarian Percentage  Green Votes  Green Percentage  Other Votes  \
# 0                        0.00        160.0              0.93        113.0
# 1                        0.00       1033.0              1.83        578.0
# 2                        0.00         46.0              0.44         65.0
# 3                        0.00         52.0              0.73         66.0
# 4                        0.00        154.0              0.86        175.0
# ...                       ...          ...               ...          ...
# 18693                    2.10          0.0              0.00        296.0
# 18694                    1.72          0.0              0.00        343.0
# 18695                    1.82          0.0              0.00        200.0
# 18696                    1.61          0.0              0.00         71.0
# 18697                    1.29          0.0              0.00         47.0
#
#        Other Percentage  Total
# 0                  0.66  17208
# 1                  1.02  56480
# 2                  0.63  10395
# 3                  0.93   7101
# 4                  0.97  17973
# ...                 ...    ...
# 18693              1.77  16698
# 18694              2.32  14787
# 18695              2.11   9459
# 18696              1.76   4032
# 18697              1.32   3560
#
# [18698 rows x 14 columns]

# %%
election_pivot[election_pivot['State'].str.contains('Virginia')]
# Out:
#        Year     State               County  Democrat Votes  \
# 2790   2000  Virginia             Accomack          5092.0
# 2791   2000  Virginia            Albemarle         16255.0
# 2792   2000  Virginia            Alleghany          2214.0
# 2793   2000  Virginia               Amelia          1754.0
# 2794   2000  Virginia              Amherst          4812.0
# ...     ...       ...                  ...             ...
# 18559  2020  Virginia         Suffolk City         28676.0
# 18560  2020  Virginia  Virginia Beach City        117393.0
# 18561  2020  Virginia      Waynesboro City          4961.0
# 18562  2020  Virginia    Williamsburg City          4790.0
# 18563  2020  Virginia      Winchester City          6610.0
#
#        Democrat Percentage  Republican Votes  Republican Percentage  \
# 2790                 42.70            6352.0                  53.27
# 2791                 44.12           18291.0                  49.64
# 2792                 43.22            2808.0                  54.81
# 2793                 36.63            2947.0                  61.55
# 2794                 41.09            6660.0                  56.86
# ...                    ...               ...                    ...
# 18559                57.77           20082.0                  40.45
# 18560                51.55          105087.0                  46.15
# 18561                46.29            5507.0                  51.39
# 18562                69.51            1963.0                  28.49
# 18563                54.57            5221.0                  43.10
#
#        Libertarian Votes  Libertarian Percentage  Green Votes  \
# 2790                 0.0                    0.00        220.0
# 2791                 0.0                    0.00       2043.0
# 2792                 0.0                    0.00         62.0
# 2793                 0.0                    0.00         40.0
# 2794                 0.0                    0.00        135.0
# ...                  ...                     ...          ...
# 18559              724.0                    1.46          0.0
# 18560             4208.0                    1.85          0.0
# 18561              209.0                    1.95          0.0
# 18562               92.0                    1.33          0.0
# 18563              213.0                    1.75          0.0
#
#        Green Percentage  Other Votes  Other Percentage   Total
# 2790               1.84        261.0              2.19   11925
# 2791               5.54        257.0              0.70   36846
# 2792               1.21         39.0              0.76    5123
# 2793               0.84         47.0              0.98    4788
# 2794               1.15        105.0              0.90   11712
# ...                 ...          ...               ...     ...
# 18559              0.00        160.0              0.32   49642
# 18560              0.00       1029.0              0.45  227717
# 18561              0.00         40.0              0.38   10717
# 18562              0.00         45.0              0.65    6890
# 18563              0.00         69.0              0.57   12113
#
# [1133 rows x 14 columns]

# %% [markdown]
# # Predict 2020
# Using actual data from 2000 to 2016

# %%
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import median_absolute_error
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
# Select relevant columns
target = 'Democrat Percentage'
features = [col for col in election_pivot.columns if col not in ['Year', 'State', 'County', target]]

# %%
# Split data into train (2000-2016) and test (2020)
train_data_rfr = election_pivot[(election_pivot['Year'] >= 2000) & (election_pivot['Year'] <= 2016)]
test_data_rfr = election_pivot[election_pivot['Year'] == 2020]

# %%
# Prepare X (features) and y (target)
X_train_rfr, y_train_rfr = train_data_rfr[features], train_data_rfr[target]
X_test_rfr, y_test_rfr = test_data_rfr[features], test_data_rfr[target]

# %%
# Train the model
rfr = RandomForestRegressor(random_state=42)
rfr.fit(X_train_rfr, y_train_rfr)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Predict for 2020
y_pred_rfr = rfr.predict(X_test_rfr)

# %%
# Convert the predictions to a DataFrame
y_pred_rfr_df = pd.DataFrame(y_pred_rfr, index=test_data_rfr.index, columns=['Predicted Democrat Percentage'])

# Include 'State' and 'County' columns in the comparison
comparison_df = pd.concat([test_data_rfr[['State', 'County', target]], y_pred_rfr_df], axis=1)

# Rename columns for clarity
comparison_df.columns = ['State', 'County', 'Actual Democrat Percentage', 'Predicted Democrat Percentage']

# Calculate the difference
comparison_df['Difference'] = comparison_df['Predicted Democrat Percentage'] - comparison_df['Actual Democrat Percentage']

# Display the comparison
comparison_df
# Out:
#          State      County  Actual Democrat Percentage  \
# 15584  Alabama     Autauga                       27.02
# 15585  Alabama     Baldwin                       22.41
# 15586  Alabama     Barbour                       45.79
# 15587  Alabama        Bibb                       20.70
# 15588  Alabama      Blount                        9.57
# ...        ...         ...                         ...
# 18693  Wyoming  Sweetwater                       22.89
# 18694  Wyoming       Teton                       66.60
# 18695  Wyoming       Uinta                       16.82
# 18696  Wyoming    Washakie                       16.15
# 18697  Wyoming      Weston                       10.11
#
#        Predicted Democrat Percentage  Difference
# 15584                        26.9532     -0.0668
# 15585                        22.4513      0.0413
# 15586                        45.8026      0.0126
# 15587                        20.7172      0.0172
# 15588                         9.3178     -0.2522
# ...                              ...         ...
# 18693                        24.9967      2.1067
# 18694                        68.1787      1.5787
# 18695                        18.5612      1.7412
# 18696                        17.7733      1.6233
# 18697                        11.1271      1.0171
#
# [3114 rows x 5 columns]

# %%
comparison_df.nlargest(10, 'Difference')
# Out:
#               State      County  Actual Democrat Percentage  \
# 17762         Texas     Roberts                        3.09
# 17582         Texas      Borden                        3.85
# 17735         Texas  Montgomery                       27.39
# 17943       Montana    Garfield                        5.04
# 17700         Texas        King                        5.03
# 16308       Indiana        Ohio                       21.72
# 17652         Texas   Glasscock                        5.97
# 16137         Idaho     Madison                       15.58
# 18286  South Dakota       Meade                       24.03
# 18280  South Dakota    Lawrence                       32.81
#
#        Predicted Democrat Percentage  Difference
# 17762                        80.8039     77.7139
# 17582                        22.4273     18.5773
# 17735                        45.0139     17.6239
# 17943                        17.2140     12.1740
# 17700                        16.9951     11.9651
# 16308                        33.0943     11.3743
# 17652                        10.2911      4.3211
# 16137                        19.3980      3.8180
# 18286                        27.7516      3.7216
# 18280                        36.5017      3.6917

# %%
comparison_df.nsmallest(10, 'Difference')
# Out:
#               State         County  Actual Democrat Percentage  \
# 17497  Pennsylvania   Philadelphia                       81.44
# 15972       Georgia        Clayton                       84.99
# 15985       Georgia         Dekalb                       83.12
# 18296  South Dakota  Oglala Lakota                       88.41
# 16011       Georgia        Hancock                       71.66
# 16063       Georgia       Rockdale                       69.92
# 15988       Georgia      Dougherty                       69.60
# 16001       Georgia         Fulton                       72.65
# 15872      Delaware     New Castle                       67.81
# 18300  South Dakota           Todd                       77.31
#
#        Predicted Democrat Percentage  Difference
# 17497                        77.0012     -4.4388
# 15972                        80.7399     -4.2501
# 15985                        79.0401     -4.0799
# 18296                        84.7742     -3.6358
# 16011                        68.1065     -3.5535
# 16063                        66.8806     -3.0394
# 15988                        66.5625     -3.0375
# 16001                        69.6637     -2.9863
# 15872                        65.1215     -2.6885
# 18300                        74.6276     -2.6824

# %%
(comparison_df['Difference'] > 0).value_counts()
# Out:
# Difference
# True     2968
# False     146
# Name: count, dtype: int64

# %%
# Prepare X (features) and y (target)
X_train_rfr, y_train_rfr = train_data_rfr[features], train_data_rfr[target]
X_test_rfr, y_test_rfr = test_data_rfr[features], test_data_rfr[target]

# %%
rfr_params = {
    'n_estimators': [50, 100, 200, 300],  # Number of trees
    'max_depth': [None, 10, 20, 30],  # Maximum depth of trees
    'min_samples_split': [2, 5, 10],  # Minimum samples per split
    'min_samples_leaf': [1, 2, 4],  # Minimum samples per leaf
    'max_features': ['sqrt', 'log2']  # Number of features to consider for splits
}

# %%
rfr = RandomForestRegressor(random_state=42)

# %%
rfr_gs = GridSearchCV(estimator=rfr, param_grid=rfr_params, 
                           cv=5, scoring='neg_mean_squared_error', 
                           n_jobs=-1, verbose=1)

# %%
# %%time
# Fit on training data
rfr_gs.fit(X_train_rfr, y_train_rfr)

# %%
import pandas as pd

# Assuming your DataFrame is named df
df_pivoted_votes = elections.pivot_table(index='County', columns=['Year', 'Party'], values='Votes', aggfunc='sum')
df_pivoted_percentage = elections.pivot_table(index='County', columns=['Year', 'Party'], values='Percentage', aggfunc='sum')

# Flatten the multi-level column index
df_pivoted_votes.columns = [f"{year} {party} Votes" for year, party in df_pivoted_votes.columns]
df_pivoted_percentage.columns = [f"{year} {party} Percentage" for year, party in df_pivoted_percentage.columns]

# Combine the two DataFrames
df_final = pd.concat([df_pivoted_votes, df_pivoted_percentage], axis=1)

# Sort by County if needed
df_final = df_final.sort_index(axis=0)

# Display the final result
df_final
# Out:
#                            2000 Democrat Votes  2000 Green Votes  \
# County
# Abbeville, South Carolina               3766.0              66.0
# Acadia, Louisiana                       8892.0             227.0
# Accomack, Virginia                      5092.0             220.0
# Ada, Idaho                             40650.0            4846.0
# Adair, Iowa                             1753.0              66.0
# ...                                        ...               ...
# Yuma, Arizona                          12055.0             495.0
# Yuma, Colorado                          1082.0              60.0
# Zapata, Texas                           1638.0              11.0
# Zavala, Texas                           2616.0              14.0
# Ziebach, South Dakota                    314.0               0.0
#
#                            2000 Other Votes  2000 Republican Votes  \
# County
# Abbeville, South Carolina              92.0                 4450.0
# Acadia, Louisiana                     305.0                13814.0
# Accomack, Virginia                    261.0                 6352.0
# Ada, Idaho                           2939.0                75050.0
# Adair, Iowa                            29.0                 2275.0
# ...                                     ...                    ...
# Yuma, Arizona                         394.0                15708.0
# Yuma, Colorado                         60.0                 3156.0
# Zapata, Texas                          14.0                  953.0
# Zavala, Texas                          10.0                  751.0
# Ziebach, South Dakota                  23.0                  384.0
#
#                            2004 Democrat Votes  2004 Other Votes  \
# County
# Abbeville, South Carolina               4389.0             100.0
# Acadia, Louisiana                       8937.0             210.0
# Accomack, Virginia                      5518.0             112.0
# Ada, Idaho                             58523.0            1838.0
# Adair, Iowa                             1844.0              32.0
# ...                                        ...               ...
# Yuma, Arizona                          16032.0             249.0
# Yuma, Colorado                          1064.0              39.0
# Zapata, Texas                           1662.0               8.0
# Zavala, Texas                           2332.0               9.0
# Ziebach, South Dakota                    641.0              28.0
#
#                            2004 Republican Votes  2008 Democrat Votes  \
# County
# Abbeville, South Carolina                 5436.0               4593.0
# Acadia, Louisiana                        16083.0               7028.0
# Accomack, Virginia                        7726.0               7607.0
# Ada, Idaho                               94641.0              82236.0
# Adair, Iowa                               2402.0               1924.0
# ...                                          ...                  ...
# Yuma, Arizona                            22184.0              18559.0
# Yuma, Colorado                            3456.0               1117.0
# Zapata, Texas                             1228.0               1939.0
# Zavala, Texas                              777.0               3263.0
# Ziebach, South Dakota                      447.0                554.0
#
#                            2008 Other Votes  2008 Republican Votes  ...  \
# County                                                              ...
# Abbeville, South Carolina             144.0                 6264.0  ...
# Acadia, Louisiana                     454.0                19228.0  ...
# Accomack, Virginia                    183.0                 7833.0  ...
# Ada, Idaho                           3838.0                93328.0  ...
# Adair, Iowa                            69.0                 2060.0  ...
# ...                                     ...                    ...  ...
# Yuma, Arizona                         479.0                24577.0  ...
# Yuma, Colorado                         80.0                 3286.0  ...
# Zapata, Texas                           8.0                  919.0  ...
# Zavala, Texas                          17.0                  596.0  ...
# Ziebach, South Dakota                  16.0                  312.0  ...
#
#                            2012 Other Percentage  2012 Republican Percentage  \
# County
# Abbeville, South Carolina                   1.38                       56.05
# Acadia, Louisiana                           1.28                       74.27
# Accomack, Virginia                          1.14                       51.17
# Ada, Idaho                                  3.24                       54.03
# Adair, Iowa                                 2.30                       52.90
# ...                                          ...                         ...
# Yuma, Arizona                               1.29                       55.66
# Yuma, Colorado                              2.18                       76.25
# Zapata, Texas                               0.54                       28.14
# Zavala, Texas                               1.01                       15.71
# Ziebach, South Dakota                       1.05                       41.26
#
#                            2016 Democrat Percentage  2016 Other Percentage  \
# County
# Abbeville, South Carolina                     34.72                   2.52
# Acadia, Louisiana                             20.58                   2.15
# Accomack, Virginia                            42.61                   3.13
# Ada, Idaho                                    38.68                  13.41
# Adair, Iowa                                   29.73                   5.69
# ...                                             ...                    ...
# Yuma, Arizona                                 46.42                   6.11
# Yuma, Colorado                                15.15                   4.49
# Zapata, Texas                                 65.66                   1.59
# Zavala, Texas                                 77.62                   1.94
# Ziebach, South Dakota                         46.02                   6.00
#
#                            2016 Republican Percentage  \
# County
# Abbeville, South Carolina                       62.77
# Acadia, Louisiana                               77.26
# Accomack, Virginia                              54.26
# Ada, Idaho                                      47.91
# Adair, Iowa                                     64.58
# ...                                               ...
# Yuma, Arizona                                   47.47
# Yuma, Colorado                                  80.36
# Zapata, Texas                                   32.75
# Zavala, Texas                                   20.44
# Ziebach, South Dakota                           47.98
#
#                            2020 Democrat Percentage  2020 Green Percentage  \
# County
# Abbeville, South Carolina                     32.98                   0.18
# Acadia, Louisiana                             19.15                    NaN
# Accomack, Virginia                            44.68                    NaN
# Ada, Idaho                                    46.47                    NaN
# Adair, Iowa                                   28.68                   0.09
# ...                                             ...                    ...
# Yuma, Arizona                                 46.09                   0.00
# Yuma, Colorado                                15.76                   0.04
# Zapata, Texas                                 47.13                   0.10
# Zavala, Texas                                 65.40                   0.27
# Ziebach, South Dakota                         53.09                    NaN
#
#                            2020 Libertarian Percentage  2020 Other Percentage  \
# County
# Abbeville, South Carolina                         0.71                   0.05
# Acadia, Louisiana                                 0.85                   0.51
# Accomack, Virginia                                1.11                   0.14
# Ada, Idaho                                        2.05                   1.10
# Adair, Iowa                                       0.84                   0.43
# ...                                                ...                    ...
# Yuma, Arizona                                     1.63                   0.00
# Yuma, Colorado                                    1.04                   0.70
# Zapata, Texas                                     0.28                   0.00
# Zavala, Texas                                     0.30                   0.00
# Ziebach, South Dakota                             2.32                    NaN
#
#                            2020 Republican Percentage
# County
# Abbeville, South Carolina                       66.06
# Acadia, Louisiana                               79.49
# Accomack, Virginia                              54.07
# Ada, Idaho                                      50.39
# Adair, Iowa                                     69.96
# ...                                               ...
# Yuma, Arizona                                   52.28
# Yuma, Colorado                                  82.45
# Zapata, Texas                                   52.48
# Zavala, Texas                                   34.03
# Ziebach, South Dakota                           44.59
#
# [3193 rows x 42 columns]

# %%
import pandas as pd

# Assuming your dataframe is called 'election_data'
pivoted_df = elections.pivot_table(index=['county_name'], columns=['year', 'party'], values='candidatevotes', aggfunc='sum')

# Flatten the MultiIndex columns (if necessary)
pivoted_df.columns = [f'{party}_{year}' for year, party in pivoted_df.columns]

# Reset the index if you want 'County' as a column
pivoted_df.reset_index(inplace=True)

# Display the reformatted dataframe
pivoted_df
# Out:
#      county_name  DEMOCRAT_2000  GREEN_2000  OTHER_2000  REPUBLICAN_2000  \
# 0      ABBEVILLE         3766.0        66.0        92.0           4450.0
# 1         ACADIA         8892.0       227.0       305.0          13814.0
# 2       ACCOMACK         5092.0       220.0       261.0           6352.0
# 3            ADA        40650.0      4846.0      2939.0          75050.0
# 4          ADAIR         9994.0       415.0       283.0          17288.0
# ...          ...            ...         ...         ...              ...
# 1887        YUBA         5546.0       507.0       236.0           9838.0
# 1888        YUMA        13137.0       555.0       454.0          18864.0
# 1889      ZAPATA         1638.0        11.0        14.0            953.0
# 1890      ZAVALA         2616.0        14.0        10.0            751.0
# 1891     ZIEBACH          314.0         0.0        23.0            384.0
#
#       DEMOCRAT_2004  OTHER_2004  REPUBLICAN_2004  DEMOCRAT_2008  OTHER_2008  \
# 0            4389.0       100.0           5436.0         4593.0       144.0
# 1            8937.0       210.0          16083.0         7028.0       454.0
# 2            5518.0       112.0           7726.0         7607.0       183.0
# 3           58523.0      1838.0          94641.0        82236.0      3838.0
# 4           11108.0       186.0          19368.0        11379.0       432.0
# ...             ...         ...              ...            ...         ...
# 1887         5687.0       257.0          12076.0         8866.0       528.0
# 1888        17096.0       288.0          25640.0        19676.0       559.0
# 1889         1662.0         8.0           1228.0         1939.0         8.0
# 1890         2332.0         9.0            777.0         3263.0        17.0
# 1891          641.0        28.0            447.0          554.0        16.0
#
#       ...  OTHER_2012  REPUBLICAN_2012  DEMOCRAT_2016  OTHER_2016  \
# 0     ...       147.0           5981.0         3741.0       271.0
# 1     ...       344.0          19931.0         5638.0       589.0
# 2     ...       183.0           8213.0         6740.0       495.0
# 3     ...      5855.0          97554.0        75677.0     26240.0
# 4     ...       447.0          17987.0         7338.0      1530.0
# ...   ...         ...              ...            ...         ...
# 1887  ...       714.0          11275.0         7910.0      1918.0
# 1888  ...       642.0          26842.0        25331.0      3455.0
# 1889  ...        19.0            997.0         2063.0        50.0
# 1890  ...        37.0            574.0         2636.0        66.0
# 1891  ...         8.0            314.0          353.0        46.0
#
#       REPUBLICAN_2016  DEMOCRAT_2020  GREEN_2020  LIBERTARIAN_2020  \
# 0              6763.0         4101.0        23.0              88.0
# 1             21162.0         5443.0         NaN             241.0
# 2              8583.0         7578.0         NaN             188.0
# 3             93752.0       120539.0         NaN            5310.0
# 4             19915.0         7687.0        47.0             314.0
# ...               ...            ...         ...               ...
# 1887          13170.0        11230.0       124.0             510.0
# 1888          29015.0        32995.0         2.0            1189.0
# 1889           1029.0         1826.0         4.0              11.0
# 1890            694.0         2864.0        12.0              13.0
# 1891            368.0          481.0         NaN              21.0
#
#       OTHER_2020  REPUBLICAN_2020
# 0            6.0           8215.0
# 1          145.0          22596.0
# 2           24.0           9172.0
# 3         2841.0         130699.0
# 4          140.0          22196.0
# ...          ...              ...
# 1887       256.0          17676.0
# 1888        35.0          40641.0
# 1889         0.0           2033.0
# 1890         0.0           1490.0
# 1891         NaN            404.0
#
# [1892 rows x 22 columns]
