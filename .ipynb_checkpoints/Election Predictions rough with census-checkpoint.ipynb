# %% [markdown]
# # NOTE - My modeling scripts basically do what I want for the time being, but there may be data cleaning issues especially with county names. Also have not added demographic, education etc to this. Other notebook has census, copy it over here.
#
# # Also have to implement much more rigorous validation, and try other models.

# %%
import pandas as pd

# %%
elections = pd.read_csv('/Users/matthewcavanaugh/Desktop/GitHub/us-presidential-elections-by-county/sources/countypres_2000-2020.csv')
elections
# Out:
#        year    state state_po county_name  county_fips        office  \
# 0      2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 1      2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 2      2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 3      2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 4      2000  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
# ...     ...      ...      ...         ...          ...           ...
# 72612  2020  WYOMING       WY    WASHAKIE      56043.0  US PRESIDENT
# 72613  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 72614  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 72615  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 72616  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
#
#                candidate        party  candidatevotes  totalvotes   version  \
# 0                AL GORE     DEMOCRAT            4942       17208  20220315
# 1         GEORGE W. BUSH   REPUBLICAN           11993       17208  20220315
# 2            RALPH NADER        GREEN             160       17208  20220315
# 3                  OTHER        OTHER             113       17208  20220315
# 4                AL GORE     DEMOCRAT           13997       56480  20220315
# ...                  ...          ...             ...         ...       ...
# 72612     DONALD J TRUMP   REPUBLICAN            3245        4032  20220315
# 72613  JOSEPH R BIDEN JR     DEMOCRAT             360        3560  20220315
# 72614       JO JORGENSEN  LIBERTARIAN              46        3560  20220315
# 72615              OTHER        OTHER              47        3560  20220315
# 72616     DONALD J TRUMP   REPUBLICAN            3107        3560  20220315
#
#         mode
# 0      TOTAL
# 1      TOTAL
# 2      TOTAL
# 3      TOTAL
# 4      TOTAL
# ...      ...
# 72612  TOTAL
# 72613  TOTAL
# 72614  TOTAL
# 72615  TOTAL
# 72616  TOTAL
#
# [72617 rows x 12 columns]

# %% [markdown]
# EDA

# %%
elections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72617 entries, 0 to 72616
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            72617 non-null  int64
#  1   state           72617 non-null  object
#  2   state_po        72617 non-null  object
#  3   county_name     72617 non-null  object
#  4   county_fips     72565 non-null  float64
#  5   office          72617 non-null  object
#  6   candidate       72617 non-null  object
#  7   party           72617 non-null  object
#  8   candidatevotes  72617 non-null  int64
#  9   totalvotes      72617 non-null  int64
#  10  version         72617 non-null  int64
#  11  mode            72617 non-null  object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 6.6+ MB

# %%
elections.isnull().sum()
# Out:
# year               0
# state              0
# state_po           0
# county_name        0
# county_fips       52
# office             0
# candidate          0
# party              0
# candidatevotes     0
# totalvotes         0
# version            0
# mode               0
# dtype: int64

# %% [markdown]
# Where are the nulls?

# %% [markdown]
# ### Here we have examples of unusual reporting statistics.

# %%
elections[elections['county_fips'].isnull()]
# Out:
#        year         state state_po        county_name  county_fips  \
# 12452  2000   CONNECTICUT       CT  STATEWIDE WRITEIN          NaN
# 12453  2000         MAINE       ME       MAINE UOCAVA          NaN
# 12454  2000  RHODE ISLAND       RI   FEDERAL PRECINCT          NaN
# 12455  2000   CONNECTICUT       CT  STATEWIDE WRITEIN          NaN
# 12456  2000         MAINE       ME       MAINE UOCAVA          NaN
# 12457  2000  RHODE ISLAND       RI   FEDERAL PRECINCT          NaN
# 12458  2000   CONNECTICUT       CT  STATEWIDE WRITEIN          NaN
# 12459  2000         MAINE       ME       MAINE UOCAVA          NaN
# 12460  2000  RHODE ISLAND       RI   FEDERAL PRECINCT          NaN
# 12461  2000   CONNECTICUT       CT  STATEWIDE WRITEIN          NaN
# 12462  2000         MAINE       ME       MAINE UOCAVA          NaN
# 12463  2000  RHODE ISLAND       RI   FEDERAL PRECINCT          NaN
# 21806  2004   CONNECTICUT       CT  STATEWIDE WRITEIN          NaN
# 21807  2004         MAINE       ME       MAINE UOCAVA          NaN
# 21808  2004  RHODE ISLAND       RI   FEDERAL PRECINCT          NaN
# 21809  2004   CONNECTICUT       CT  STATEWIDE WRITEIN          NaN
# 21810  2004         MAINE       ME       MAINE UOCAVA          NaN
# 21811  2004  RHODE ISLAND       RI   FEDERAL PRECINCT          NaN
# 21812  2004   CONNECTICUT       CT  STATEWIDE WRITEIN          NaN
# 21813  2004         MAINE       ME       MAINE UOCAVA          NaN
# 21814  2004  RHODE ISLAND       RI   FEDERAL PRECINCT          NaN
# 31157  2008   CONNECTICUT       CT  STATEWIDE WRITEIN          NaN
# 31158  2008         MAINE       ME       MAINE UOCAVA          NaN
# 31159  2008  RHODE ISLAND       RI   FEDERAL PRECINCT          NaN
# 31160  2008   CONNECTICUT       CT  STATEWIDE WRITEIN          NaN
# 31161  2008         MAINE       ME       MAINE UOCAVA          NaN
# 31162  2008  RHODE ISLAND       RI   FEDERAL PRECINCT          NaN
# 31163  2008   CONNECTICUT       CT  STATEWIDE WRITEIN          NaN
# 31164  2008         MAINE       ME       MAINE UOCAVA          NaN
# 31165  2008  RHODE ISLAND       RI   FEDERAL PRECINCT          NaN
# 40508  2012   CONNECTICUT       CT  STATEWIDE WRITEIN          NaN
# 40509  2012         MAINE       ME       MAINE UOCAVA          NaN
# 40510  2012  RHODE ISLAND       RI   FEDERAL PRECINCT          NaN
# 40511  2012   CONNECTICUT       CT  STATEWIDE WRITEIN          NaN
# 40512  2012         MAINE       ME       MAINE UOCAVA          NaN
# 40513  2012  RHODE ISLAND       RI   FEDERAL PRECINCT          NaN
# 40514  2012   CONNECTICUT       CT  STATEWIDE WRITEIN          NaN
# 40515  2012         MAINE       ME       MAINE UOCAVA          NaN
# 40516  2012  RHODE ISLAND       RI   FEDERAL PRECINCT          NaN
# 49859  2016   CONNECTICUT       CT  STATEWIDE WRITEIN          NaN
# 49860  2016         MAINE       ME       MAINE UOCAVA          NaN
# 49861  2016  RHODE ISLAND       RI   FEDERAL PRECINCT          NaN
# 49862  2016   CONNECTICUT       CT  STATEWIDE WRITEIN          NaN
# 49863  2016         MAINE       ME       MAINE UOCAVA          NaN
# 49864  2016  RHODE ISLAND       RI   FEDERAL PRECINCT          NaN
# 49865  2016   CONNECTICUT       CT  STATEWIDE WRITEIN          NaN
# 49866  2016         MAINE       ME       MAINE UOCAVA          NaN
# 49867  2016  RHODE ISLAND       RI   FEDERAL PRECINCT          NaN
# 63983  2020  RHODE ISLAND       RI   FEDERAL PRECINCT          NaN
# 63984  2020  RHODE ISLAND       RI   FEDERAL PRECINCT          NaN
# 63985  2020  RHODE ISLAND       RI   FEDERAL PRECINCT          NaN
# 63986  2020  RHODE ISLAND       RI   FEDERAL PRECINCT          NaN
#
#              office          candidate        party  candidatevotes  \
# 12452  US PRESIDENT            AL GORE     DEMOCRAT               0
# 12453  US PRESIDENT            AL GORE     DEMOCRAT               0
# 12454  US PRESIDENT            AL GORE     DEMOCRAT               0
# 12455  US PRESIDENT     GEORGE W. BUSH   REPUBLICAN               0
# 12456  US PRESIDENT     GEORGE W. BUSH   REPUBLICAN               0
# 12457  US PRESIDENT     GEORGE W. BUSH   REPUBLICAN               0
# 12458  US PRESIDENT        RALPH NADER        GREEN               0
# 12459  US PRESIDENT        RALPH NADER        GREEN               0
# 12460  US PRESIDENT        RALPH NADER        GREEN               0
# 12461  US PRESIDENT              OTHER        OTHER               0
# 12462  US PRESIDENT              OTHER        OTHER               0
# 12463  US PRESIDENT              OTHER        OTHER               0
# 21806  US PRESIDENT         JOHN KERRY     DEMOCRAT               0
# 21807  US PRESIDENT         JOHN KERRY     DEMOCRAT               0
# 21808  US PRESIDENT         JOHN KERRY     DEMOCRAT               0
# 21809  US PRESIDENT     GEORGE W. BUSH   REPUBLICAN               0
# 21810  US PRESIDENT     GEORGE W. BUSH   REPUBLICAN               0
# 21811  US PRESIDENT     GEORGE W. BUSH   REPUBLICAN               0
# 21812  US PRESIDENT              OTHER        OTHER               0
# 21813  US PRESIDENT              OTHER        OTHER               0
# 21814  US PRESIDENT              OTHER        OTHER               0
# 31157  US PRESIDENT       BARACK OBAMA     DEMOCRAT               0
# 31158  US PRESIDENT       BARACK OBAMA     DEMOCRAT               0
# 31159  US PRESIDENT       BARACK OBAMA     DEMOCRAT               0
# 31160  US PRESIDENT        JOHN MCCAIN   REPUBLICAN               0
# 31161  US PRESIDENT        JOHN MCCAIN   REPUBLICAN               0
# 31162  US PRESIDENT        JOHN MCCAIN   REPUBLICAN               0
# 31163  US PRESIDENT              OTHER        OTHER               0
# 31164  US PRESIDENT              OTHER        OTHER               0
# 31165  US PRESIDENT              OTHER        OTHER               0
# 40508  US PRESIDENT       BARACK OBAMA     DEMOCRAT               0
# 40509  US PRESIDENT       BARACK OBAMA     DEMOCRAT            2071
# 40510  US PRESIDENT       BARACK OBAMA     DEMOCRAT             268
# 40511  US PRESIDENT        MITT ROMNEY   REPUBLICAN               0
# 40512  US PRESIDENT        MITT ROMNEY   REPUBLICAN             858
# 40513  US PRESIDENT        MITT ROMNEY   REPUBLICAN              53
# 40514  US PRESIDENT              OTHER        OTHER             918
# 40515  US PRESIDENT              OTHER        OTHER             125
# 40516  US PRESIDENT              OTHER        OTHER              12
# 49859  US PRESIDENT    HILLARY CLINTON     DEMOCRAT               0
# 49860  US PRESIDENT    HILLARY CLINTON     DEMOCRAT            3017
# 49861  US PRESIDENT    HILLARY CLINTON     DEMOCRAT             637
# 49862  US PRESIDENT       DONALD TRUMP   REPUBLICAN               0
# 49863  US PRESIDENT       DONALD TRUMP   REPUBLICAN             648
# 49864  US PRESIDENT       DONALD TRUMP   REPUBLICAN              53
# 49865  US PRESIDENT              OTHER        OTHER            2616
# 49866  US PRESIDENT              OTHER        OTHER             321
# 49867  US PRESIDENT              OTHER        OTHER              38
# 63983  US PRESIDENT  JOSEPH R BIDEN JR     DEMOCRAT            1276
# 63984  US PRESIDENT       JO JORGENSEN  LIBERTARIAN               6
# 63985  US PRESIDENT              OTHER        OTHER               7
# 63986  US PRESIDENT     DONALD J TRUMP   REPUBLICAN              85
#
#        totalvotes   version   mode
# 12452           0  20220315  TOTAL
# 12453           0  20220315  TOTAL
# 12454           0  20220315  TOTAL
# 12455           0  20220315  TOTAL
# 12456           0  20220315  TOTAL
# 12457           0  20220315  TOTAL
# 12458           0  20220315  TOTAL
# 12459           0  20220315  TOTAL
# 12460           0  20220315  TOTAL
# 12461           0  20220315  TOTAL
# 12462           0  20220315  TOTAL
# 12463           0  20220315  TOTAL
# 21806           0  20220315  TOTAL
# 21807           0  20220315  TOTAL
# 21808           0  20220315  TOTAL
# 21809           0  20220315  TOTAL
# 21810           0  20220315  TOTAL
# 21811           0  20220315  TOTAL
# 21812           0  20220315  TOTAL
# 21813           0  20220315  TOTAL
# 21814           0  20220315  TOTAL
# 31157           0  20220315  TOTAL
# 31158           0  20220315  TOTAL
# 31159           0  20220315  TOTAL
# 31160           0  20220315  TOTAL
# 31161           0  20220315  TOTAL
# 31162           0  20220315  TOTAL
# 31163           0  20220315  TOTAL
# 31164           0  20220315  TOTAL
# 31165           0  20220315  TOTAL
# 40508         918  20220315  TOTAL
# 40509        3054  20220315  TOTAL
# 40510         333  20220315  TOTAL
# 40511         918  20220315  TOTAL
# 40512        3054  20220315  TOTAL
# 40513         333  20220315  TOTAL
# 40514         918  20220315  TOTAL
# 40515        3054  20220315  TOTAL
# 40516         333  20220315  TOTAL
# 49859        2616  20220315  TOTAL
# 49860        3986  20220315  TOTAL
# 49861         728  20220315  TOTAL
# 49862        2616  20220315  TOTAL
# 49863        3986  20220315  TOTAL
# 49864         728  20220315  TOTAL
# 49865        2616  20220315  TOTAL
# 49866        3986  20220315  TOTAL
# 49867         728  20220315  TOTAL
# 63983        1374  20220315  TOTAL
# 63984        1374  20220315  TOTAL
# 63985        1374  20220315  TOTAL
# 63986        1374  20220315  TOTAL

# %% [markdown]
# These are unusual administrative units that have no votes recorded. It's safe to drop them.

# %%
elections.dropna(inplace=True)

# %%
# Combine 'County' and 'State' columns
#elections['county_name'] = elections['county_name'] + ', ' + elections['state']

#elections.drop('state', axis=1, inplace=True)
elections.drop('state_po', axis=1, inplace=True)
elections.drop('county_fips', axis=1, inplace=True)
elections.drop('office', axis=1, inplace=True)
elections.drop('version', axis=1, inplace=True)
elections.drop('mode', axis=1, inplace=True)
elections.drop('candidate', axis=1, inplace=True)

# Result
elections
# Out:
#        year    state county_name        party  candidatevotes  totalvotes
# 0      2000  ALABAMA     AUTAUGA     DEMOCRAT            4942       17208
# 1      2000  ALABAMA     AUTAUGA   REPUBLICAN           11993       17208
# 2      2000  ALABAMA     AUTAUGA        GREEN             160       17208
# 3      2000  ALABAMA     AUTAUGA        OTHER             113       17208
# 4      2000  ALABAMA     BALDWIN     DEMOCRAT           13997       56480
# ...     ...      ...         ...          ...             ...         ...
# 72612  2020  WYOMING    WASHAKIE   REPUBLICAN            3245        4032
# 72613  2020  WYOMING      WESTON     DEMOCRAT             360        3560
# 72614  2020  WYOMING      WESTON  LIBERTARIAN              46        3560
# 72615  2020  WYOMING      WESTON        OTHER              47        3560
# 72616  2020  WYOMING      WESTON   REPUBLICAN            3107        3560
#
# [72565 rows x 6 columns]

# %%
elections = elections.rename(columns={'year': 'Year'})
elections = elections.rename(columns={'state': 'State'})
elections = elections.rename(columns={'county_name': 'County'})
elections = elections.rename(columns={'state': 'State'})
elections = elections.rename(columns={'party': 'Party'})
elections = elections.rename(columns={'candidatevotes': 'Votes'})
elections = elections.rename(columns={'totalvotes': 'Total'})

elections
# Out:
#        Year    State    County        Party  Votes  Total
# 0      2000  ALABAMA   AUTAUGA     DEMOCRAT   4942  17208
# 1      2000  ALABAMA   AUTAUGA   REPUBLICAN  11993  17208
# 2      2000  ALABAMA   AUTAUGA        GREEN    160  17208
# 3      2000  ALABAMA   AUTAUGA        OTHER    113  17208
# 4      2000  ALABAMA   BALDWIN     DEMOCRAT  13997  56480
# ...     ...      ...       ...          ...    ...    ...
# 72612  2020  WYOMING  WASHAKIE   REPUBLICAN   3245   4032
# 72613  2020  WYOMING    WESTON     DEMOCRAT    360   3560
# 72614  2020  WYOMING    WESTON  LIBERTARIAN     46   3560
# 72615  2020  WYOMING    WESTON        OTHER     47   3560
# 72616  2020  WYOMING    WESTON   REPUBLICAN   3107   3560
#
# [72565 rows x 6 columns]

# %%
def clean_text(text):
    if isinstance(text, str):
        return text.title()  # Capitalizes the first letter of each word and makes the rest lowercase
    return text  # Return text unchanged if it's not a string

# Apply this function to a specific column in your dataframe
elections['County'] = elections['County'].apply(clean_text)
elections['Party'] = elections['Party'].apply(clean_text)
elections['State'] = elections['State'].apply(clean_text)

# %%
elections
# Out:
#        Year    State    County        Party  Votes  Total
# 0      2000  Alabama   Autauga     Democrat   4942  17208
# 1      2000  Alabama   Autauga   Republican  11993  17208
# 2      2000  Alabama   Autauga        Green    160  17208
# 3      2000  Alabama   Autauga        Other    113  17208
# 4      2000  Alabama   Baldwin     Democrat  13997  56480
# ...     ...      ...       ...          ...    ...    ...
# 72612  2020  Wyoming  Washakie   Republican   3245   4032
# 72613  2020  Wyoming    Weston     Democrat    360   3560
# 72614  2020  Wyoming    Weston  Libertarian     46   3560
# 72615  2020  Wyoming    Weston        Other     47   3560
# 72616  2020  Wyoming    Weston   Republican   3107   3560
#
# [72565 rows x 6 columns]

# %% [markdown]
# Virginia is an unusual case with many independent cities. Let's check it to ensure the capitlization has worked the way we want.

# %%
elections[elections['State'].str.contains('Virginia')]
# Out:
#        Year     State           County       Party  Votes  Total
# 11160  2000  Virginia         Accomack    Democrat   5092  11925
# 11161  2000  Virginia         Accomack  Republican   6352  11925
# 11162  2000  Virginia         Accomack       Green    220  11925
# 11163  2000  Virginia         Accomack       Other    261  11925
# 11164  2000  Virginia        Albemarle    Democrat  16255  36846
# ...     ...       ...              ...         ...    ...    ...
# 71965  2020  Virginia  Winchester City       Other     24  12113
# 71966  2020  Virginia  Winchester City       Other      0  12113
# 71967  2020  Virginia  Winchester City  Republican   2825  12113
# 71968  2020  Virginia  Winchester City  Republican   2370  12113
# 71969  2020  Virginia  Winchester City  Republican     26  12113
#
# [4836 rows x 6 columns]

# %% [markdown]
# We may have no choice but to drop Alaska as it does not have consistent administrative units by which metrics are kept.

# %%
elections = elections[~elections['State'].str.contains('Alaska', na=False)]

# %%
elections['Party'].value_counts()
# Out:
# Party
# Democrat       20644
# Republican     20644
# Other          19553
# Green           5950
# Libertarian     4913
# Name: count, dtype: int64

# %%
elections['Percentage'] = round((elections['Votes'] / elections['Total'] * 100), 2)
elections
# Out:
# /var/folders/cf/4zrkk0lx1nbdx9tpklpk4jc00000gn/T/ipykernel_95429/3329014358.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elections['Percentage'] = round((elections['Votes'] / elections['Total'] * 100), 2)
#        Year    State    County        Party  Votes  Total  Percentage
# 0      2000  Alabama   Autauga     Democrat   4942  17208       28.72
# 1      2000  Alabama   Autauga   Republican  11993  17208       69.69
# 2      2000  Alabama   Autauga        Green    160  17208        0.93
# 3      2000  Alabama   Autauga        Other    113  17208        0.66
# 4      2000  Alabama   Baldwin     Democrat  13997  56480       24.78
# ...     ...      ...       ...          ...    ...    ...         ...
# 72612  2020  Wyoming  Washakie   Republican   3245   4032       80.48
# 72613  2020  Wyoming    Weston     Democrat    360   3560       10.11
# 72614  2020  Wyoming    Weston  Libertarian     46   3560        1.29
# 72615  2020  Wyoming    Weston        Other     47   3560        1.32
# 72616  2020  Wyoming    Weston   Republican   3107   3560       87.28
#
# [71704 rows x 7 columns]

# %%
elections = elections[['Year', 'State', 'County', 'Party', 'Votes', 'Percentage', 'Total']]
elections
# Out:
#        Year    State    County        Party  Votes  Percentage  Total
# 0      2000  Alabama   Autauga     Democrat   4942       28.72  17208
# 1      2000  Alabama   Autauga   Republican  11993       69.69  17208
# 2      2000  Alabama   Autauga        Green    160        0.93  17208
# 3      2000  Alabama   Autauga        Other    113        0.66  17208
# 4      2000  Alabama   Baldwin     Democrat  13997       24.78  56480
# ...     ...      ...       ...          ...    ...         ...    ...
# 72612  2020  Wyoming  Washakie   Republican   3245       80.48   4032
# 72613  2020  Wyoming    Weston     Democrat    360       10.11   3560
# 72614  2020  Wyoming    Weston  Libertarian     46        1.29   3560
# 72615  2020  Wyoming    Weston        Other     47        1.32   3560
# 72616  2020  Wyoming    Weston   Republican   3107       87.28   3560
#
# [71704 rows x 7 columns]

# %%
# Pivot the DataFrame for vote totals by year and county for each party
vote_totals = elections.pivot_table(index=['Year', 'State', 'County'], columns='Party', values='Votes', aggfunc='sum')

# Pivot the DataFrame for percentages by year and county for each party
percentage_totals = elections.pivot_table(index=['Year', 'State', 'County'], columns='Party', values='Percentage', aggfunc='sum')

# Merge the two DataFrames together: vote totals and percentages
election_pivot = pd.concat([vote_totals, percentage_totals], axis=1, keys=['Votes', 'Percentage'])

# Flatten the MultiIndex columns and rename them according to the required format
election_pivot.columns = [f'{party} {stat}' for stat, party in election_pivot.columns]

# Reorder columns to keep the parties together (Democratic, Republican, etc.)
party_order = ['Democrat', 'Republican', 'Libertarian', 'Green', 'Other']  # You can add or adjust parties as needed
ordered_columns = []

for party in party_order:
    if f'{party} Votes' in election_pivot.columns:
        ordered_columns.append(f'{party} Votes')
    if f'{party} Percentage' in election_pivot.columns:
        ordered_columns.append(f'{party} Percentage')

# Reindex the DataFrame to match the desired column order
election_pivot = election_pivot[ordered_columns]

# Include the 'Total' column in the final DataFrame
election_results_totals = elections[['Year', 'State', 'County', 'Total']].drop_duplicates()

# Merge the 'Total' column back into the pivoted DataFrame
election_pivot = pd.merge(election_results_totals, election_pivot, on=['Year', 'State', 'County'])

# Move the 'Total' column to the end
election_pivot = election_pivot[[col for col in election_pivot.columns if col != 'Total'] + ['Total']]

# Fill nulls with 0
election_pivot.fillna(0, inplace=True)

# Display the pivoted DataFrame with the correct column ordering and Total column at the end
election_pivot
# Out:
#        Year    State      County  Democrat Votes  Democrat Percentage  \
# 0      2000  Alabama     Autauga          4942.0                28.72
# 1      2000  Alabama     Baldwin         13997.0                24.78
# 2      2000  Alabama     Barbour          5188.0                49.91
# 3      2000  Alabama        Bibb          2710.0                38.16
# 4      2000  Alabama      Blount          4977.0                27.69
# ...     ...      ...         ...             ...                  ...
# 18677  2020  Wyoming  Sweetwater          3823.0                22.89
# 18678  2020  Wyoming       Teton          9848.0                66.60
# 18679  2020  Wyoming       Uinta          1591.0                16.82
# 18680  2020  Wyoming    Washakie           651.0                16.15
# 18681  2020  Wyoming      Weston           360.0                10.11
#
#        Republican Votes  Republican Percentage  Libertarian Votes  \
# 0               11993.0                  69.69                0.0
# 1               40872.0                  72.37                0.0
# 2                5096.0                  49.02                0.0
# 3                4273.0                  60.17                0.0
# 4               12667.0                  70.48                0.0
# ...                 ...                    ...                ...
# 18677           12229.0                  73.24              350.0
# 18678            4341.0                  29.36              255.0
# 18679            7496.0                  79.25              172.0
# 18680            3245.0                  80.48               65.0
# 18681            3107.0                  87.28               46.0
#
#        Libertarian Percentage  Green Votes  Green Percentage  Other Votes  \
# 0                        0.00        160.0              0.93        113.0
# 1                        0.00       1033.0              1.83        578.0
# 2                        0.00         46.0              0.44         65.0
# 3                        0.00         52.0              0.73         66.0
# 4                        0.00        154.0              0.86        175.0
# ...                       ...          ...               ...          ...
# 18677                    2.10          0.0              0.00        296.0
# 18678                    1.72          0.0              0.00        343.0
# 18679                    1.82          0.0              0.00        200.0
# 18680                    1.61          0.0              0.00         71.0
# 18681                    1.29          0.0              0.00         47.0
#
#        Other Percentage  Total
# 0                  0.66  17208
# 1                  1.02  56480
# 2                  0.63  10395
# 3                  0.93   7101
# 4                  0.97  17973
# ...                 ...    ...
# 18677              1.77  16698
# 18678              2.32  14787
# 18679              2.11   9459
# 18680              1.76   4032
# 18681              1.32   3560
#
# [18682 rows x 14 columns]

# %%
election_pivot['D-R margin'] = election_pivot['Democrat Percentage'] - election_pivot['Republican Percentage']

# %%
election_pivot['Two party vote share'] = election_pivot['Democrat Percentage'] + election_pivot['Republican Percentage']

# %%
# Move the 'Total' column to the end
election_pivot = election_pivot[[col for col in election_pivot.columns if col != 'Total'] + ['Total']]

# %%
election_pivot
# Out:
#        Year    State      County  Democrat Votes  Democrat Percentage  \
# 0      2000  Alabama     Autauga          4942.0                28.72
# 1      2000  Alabama     Baldwin         13997.0                24.78
# 2      2000  Alabama     Barbour          5188.0                49.91
# 3      2000  Alabama        Bibb          2710.0                38.16
# 4      2000  Alabama      Blount          4977.0                27.69
# ...     ...      ...         ...             ...                  ...
# 18677  2020  Wyoming  Sweetwater          3823.0                22.89
# 18678  2020  Wyoming       Teton          9848.0                66.60
# 18679  2020  Wyoming       Uinta          1591.0                16.82
# 18680  2020  Wyoming    Washakie           651.0                16.15
# 18681  2020  Wyoming      Weston           360.0                10.11
#
#        Republican Votes  Republican Percentage  Libertarian Votes  \
# 0               11993.0                  69.69                0.0
# 1               40872.0                  72.37                0.0
# 2                5096.0                  49.02                0.0
# 3                4273.0                  60.17                0.0
# 4               12667.0                  70.48                0.0
# ...                 ...                    ...                ...
# 18677           12229.0                  73.24              350.0
# 18678            4341.0                  29.36              255.0
# 18679            7496.0                  79.25              172.0
# 18680            3245.0                  80.48               65.0
# 18681            3107.0                  87.28               46.0
#
#        Libertarian Percentage  Green Votes  Green Percentage  Other Votes  \
# 0                        0.00        160.0              0.93        113.0
# 1                        0.00       1033.0              1.83        578.0
# 2                        0.00         46.0              0.44         65.0
# 3                        0.00         52.0              0.73         66.0
# 4                        0.00        154.0              0.86        175.0
# ...                       ...          ...               ...          ...
# 18677                    2.10          0.0              0.00        296.0
# 18678                    1.72          0.0              0.00        343.0
# 18679                    1.82          0.0              0.00        200.0
# 18680                    1.61          0.0              0.00         71.0
# 18681                    1.29          0.0              0.00         47.0
#
#        Other Percentage  D-R margin  Two party vote share  Total
# 0                  0.66      -40.97                 98.41  17208
# 1                  1.02      -47.59                 97.15  56480
# 2                  0.63        0.89                 98.93  10395
# 3                  0.93      -22.01                 98.33   7101
# 4                  0.97      -42.79                 98.17  17973
# ...                 ...         ...                   ...    ...
# 18677              1.77      -50.35                 96.13  16698
# 18678              2.32       37.24                 95.96  14787
# 18679              2.11      -62.43                 96.07   9459
# 18680              1.76      -64.33                 96.63   4032
# 18681              1.32      -77.17                 97.39   3560
#
# [18682 rows x 16 columns]

# %%
election_pivot.nsmallest(10, 'Two party vote share')
# Out:
#        Year         State        County  Democrat Votes  Democrat Percentage  \
# 1797   2000      Missouri   Kansas City             0.0                 0.00
# 15205  2016          Utah         Cache          8563.0                18.55
# 13008  2016         Idaho       Madison          1201.0                 7.66
# 15227  2016          Utah          Utah         28522.0                14.15
# 8206   2008  North Dakota         Grant           280.0                21.07
# 15208  2016          Utah         Davis         28776.0                20.79
# 7832   2008       Montana  Powder River           208.0                14.81
# 15225  2016          Utah        Tooele          4573.0                20.95
# 15217  2016          Utah        Morgan           577.0                11.11
# 15204  2016          Utah     Box Elder          2282.0                11.56
#
#        Republican Votes  Republican Percentage  Libertarian Votes  \
# 1797                0.0                   0.00                0.0
# 15205           21139.0                  45.80                0.0
# 13008            8941.0                  56.99                0.0
# 15227          102182.0                  50.70                0.0
# 8206              587.0                  44.17                0.0
# 15208           62219.0                  44.95                0.0
# 7832              802.0                  57.12                0.0
# 15225           11169.0                  51.17                0.0
# 15217            3188.0                  61.40                0.0
# 15204           12230.0                  61.97                0.0
#
#        Libertarian Percentage  Green Votes  Green Percentage  Other Votes  \
# 1797                      0.0          0.0               0.0          0.0
# 15205                     0.0          0.0               0.0      16455.0
# 13008                     0.0          0.0               0.0       5546.0
# 15227                     0.0          0.0               0.0      70847.0
# 8206                      0.0          0.0               0.0        462.0
# 15208                     0.0          0.0               0.0      47416.0
# 7832                      0.0          0.0               0.0        394.0
# 15225                     0.0          0.0               0.0       6087.0
# 15217                     0.0          0.0               0.0       1427.0
# 15204                     0.0          0.0               0.0       5223.0
#
#        Other Percentage  D-R margin  Two party vote share   Total
# 1797               0.00        0.00                  0.00       0
# 15205             35.65      -27.25                 64.35   46157
# 13008             35.35      -49.33                 64.65   15688
# 15227             35.15      -36.55                 64.85  201551
# 8206              34.76      -23.10                 65.24    1329
# 15208             34.26      -24.16                 65.74  138411
# 7832              28.06      -42.31                 71.93    1404
# 15225             27.88      -30.22                 72.12   21829
# 15217             27.48      -50.29                 72.51    5192
# 15204             26.47      -50.41                 73.53   19735

# %% [markdown]
# In some states in some years, certain minor parties did not file a candidate. However, it is suspicious if an entity has zero votes for either the Republican or Democratic parties. Let's drop those.

# %%
#This is just for debugging, can delete later
#election_pivot[election_pivot['State'].str.contains('Virginia')]

# %% [markdown]
# # Volatility
# # For each county (i.e. State/County pair), find the average and total absolute swings between elections.
# Add up the 2000-2004 swing, 2004-2008 swing, 2008-2012 swing, 2012-2016 swing, and 2016-2020 swing. This will identify *volatile* counties prone to large swings from year to year. A *volatile* county is not necessarily the same as a county that changes loyalty over time.

# %%
dupes = election_pivot[election_pivot.duplicated(subset=['County', 'State', 'Year'], keep=False)]

# %%
election_pivot = election_pivot.drop_duplicates(subset=['County', 'State', 'Year'])

# %%
election_pivot['CountyState'] = election_pivot['County'] + ', ' + election_pivot['State']
pivot = election_pivot.pivot(index='CountyState', columns='Year', values='D-R margin')

# %%
pivot
# Out:
# Year                        2000   2004   2008   2012   2016   2020
# CountyState
# Abbeville, South Carolina  -8.17 -10.55 -15.19 -13.48 -28.05 -33.08
# Acadia, Louisiana         -21.19 -28.33 -45.68 -49.82 -56.68 -60.34
# Accomack, Virginia        -10.57 -16.54  -1.45  -3.48 -11.65  -9.39
# Ada, Idaho                -27.86 -23.30  -6.18 -11.31  -9.23  -3.92
# Adair, Iowa               -12.66 -13.05  -3.36  -8.11 -34.85 -41.28
# ...                          ...    ...    ...    ...    ...    ...
# Yuma, Arizona             -12.75 -15.99 -13.80 -12.61  -1.05  -6.19
# Yuma, Colorado            -47.59 -52.47 -48.38 -54.69 -65.21 -66.69
# Zapata, Texas              26.18  14.98  35.59  43.18  32.91  -5.35
# Zavala, Texas              55.00  49.87  68.80  67.56  57.18  31.37
# Ziebach, South Dakota      -9.71  17.39  27.44  16.43  -1.96   8.50
#
# [3149 rows x 6 columns]

# %%
pivot['2000-2004 swing'] = pivot[2004] - pivot[2000]
pivot['2000-2004 absolute swing'] = pivot['2000-2004 swing'].abs()
pivot['2004-2008 swing'] = pivot[2008] - pivot[2004]
pivot['2004-2008 absolute swing'] = pivot['2004-2008 swing'].abs()
pivot['2008-2012 swing'] = pivot[2012] - pivot[2008]
pivot['2008-2012 absolute swing'] = pivot['2008-2012 swing'].abs()
pivot['2012-2016 swing'] = pivot[2016] - pivot[2012]
pivot['2012-2016 absolute swing'] = pivot['2012-2016 swing'].abs()
pivot['2016-2020 swing'] = pivot[2020] - pivot[2016]
pivot['2016-2020 absolute swing'] = pivot['2016-2020 swing'].abs()
pivot['Total swing'] = pivot['2000-2004 swing'] + pivot['2004-2008 swing'] + pivot['2008-2012 swing'] + pivot['2012-2016 swing'] + pivot['2016-2020 swing']
pivot['Cumulative absolute swing'] = pivot['2000-2004 absolute swing'] + pivot['2004-2008 absolute swing'] + pivot['2008-2012 absolute swing'] + pivot['2012-2016 absolute swing'] + pivot['2016-2020 absolute swing']

# %%
pivot
# Out:
# Year                        2000   2004   2008   2012   2016   2020  \
# CountyState
# Abbeville, South Carolina  -8.17 -10.55 -15.19 -13.48 -28.05 -33.08
# Acadia, Louisiana         -21.19 -28.33 -45.68 -49.82 -56.68 -60.34
# Accomack, Virginia        -10.57 -16.54  -1.45  -3.48 -11.65  -9.39
# Ada, Idaho                -27.86 -23.30  -6.18 -11.31  -9.23  -3.92
# Adair, Iowa               -12.66 -13.05  -3.36  -8.11 -34.85 -41.28
# ...                          ...    ...    ...    ...    ...    ...
# Yuma, Arizona             -12.75 -15.99 -13.80 -12.61  -1.05  -6.19
# Yuma, Colorado            -47.59 -52.47 -48.38 -54.69 -65.21 -66.69
# Zapata, Texas              26.18  14.98  35.59  43.18  32.91  -5.35
# Zavala, Texas              55.00  49.87  68.80  67.56  57.18  31.37
# Ziebach, South Dakota      -9.71  17.39  27.44  16.43  -1.96   8.50
#
# Year                       2000-2004 swing  2000-2004 absolute swing  \
# CountyState
# Abbeville, South Carolina            -2.38                      2.38
# Acadia, Louisiana                    -7.14                      7.14
# Accomack, Virginia                   -5.97                      5.97
# Ada, Idaho                            4.56                      4.56
# Adair, Iowa                          -0.39                      0.39
# ...                                    ...                       ...
# Yuma, Arizona                        -3.24                      3.24
# Yuma, Colorado                       -4.88                      4.88
# Zapata, Texas                       -11.20                     11.20
# Zavala, Texas                        -5.13                      5.13
# Ziebach, South Dakota                27.10                     27.10
#
# Year                       2004-2008 swing  2004-2008 absolute swing  \
# CountyState
# Abbeville, South Carolina            -4.64                      4.64
# Acadia, Louisiana                   -17.35                     17.35
# Accomack, Virginia                   15.09                     15.09
# Ada, Idaho                           17.12                     17.12
# Adair, Iowa                           9.69                      9.69
# ...                                    ...                       ...
# Yuma, Arizona                         2.19                      2.19
# Yuma, Colorado                        4.09                      4.09
# Zapata, Texas                        20.61                     20.61
# Zavala, Texas                        18.93                     18.93
# Ziebach, South Dakota                10.05                     10.05
#
# Year                       2008-2012 swing  2008-2012 absolute swing  \
# CountyState
# Abbeville, South Carolina             1.71                      1.71
# Acadia, Louisiana                    -4.14                      4.14
# Accomack, Virginia                   -2.03                      2.03
# Ada, Idaho                           -5.13                      5.13
# Adair, Iowa                          -4.75                      4.75
# ...                                    ...                       ...
# Yuma, Arizona                         1.19                      1.19
# Yuma, Colorado                       -6.31                      6.31
# Zapata, Texas                         7.59                      7.59
# Zavala, Texas                        -1.24                      1.24
# Ziebach, South Dakota               -11.01                     11.01
#
# Year                       2012-2016 swing  2012-2016 absolute swing  \
# CountyState
# Abbeville, South Carolina           -14.57                     14.57
# Acadia, Louisiana                    -6.86                      6.86
# Accomack, Virginia                   -8.17                      8.17
# Ada, Idaho                            2.08                      2.08
# Adair, Iowa                         -26.74                     26.74
# ...                                    ...                       ...
# Yuma, Arizona                        11.56                     11.56
# Yuma, Colorado                      -10.52                     10.52
# Zapata, Texas                       -10.27                     10.27
# Zavala, Texas                       -10.38                     10.38
# Ziebach, South Dakota               -18.39                     18.39
#
# Year                       2016-2020 swing  2016-2020 absolute swing  \
# CountyState
# Abbeville, South Carolina            -5.03                      5.03
# Acadia, Louisiana                    -3.66                      3.66
# Accomack, Virginia                    2.26                      2.26
# Ada, Idaho                            5.31                      5.31
# Adair, Iowa                          -6.43                      6.43
# ...                                    ...                       ...
# Yuma, Arizona                        -5.14                      5.14
# Yuma, Colorado                       -1.48                      1.48
# Zapata, Texas                       -38.26                     38.26
# Zavala, Texas                       -25.81                     25.81
# Ziebach, South Dakota                10.46                     10.46
#
# Year                       Total swing  Cumulative absolute swing
# CountyState
# Abbeville, South Carolina       -24.91                      28.33
# Acadia, Louisiana               -39.15                      39.15
# Accomack, Virginia                1.18                      33.52
# Ada, Idaho                       23.94                      34.20
# Adair, Iowa                     -28.62                      48.00
# ...                                ...                        ...
# Yuma, Arizona                     6.56                      23.32
# Yuma, Colorado                  -19.10                      27.28
# Zapata, Texas                   -31.53                      87.93
# Zavala, Texas                   -23.63                      61.49
# Ziebach, South Dakota            18.21                      77.01
#
# [3149 rows x 18 columns]

# %%
pivot['Cumulative absolute swing'].nlargest(10)
# Out:
# CountyState
# Richmond, Virginia      107.97
# Elliott, Kentucky       102.58
# Starr, Texas            100.89
# Maverick, Texas          99.21
# Fairfax, Virginia        98.48
# Jackson, Tennessee       96.43
# Cache, Utah              96.01
# Grundy, Tennessee        95.98
# Mingo, West Virginia     93.05
# Smith, Tennessee         92.96
# Name: Cumulative absolute swing, dtype: float64

# %%
election_pivot.nsmallest(10, 'Two party vote share')

# %% [markdown]
# To accomplish this, we will first create individual DataFrames for each election.

# %%
election2000 = election_pivot[election_pivot['Year'] == 2000]
election2004 = election_pivot[election_pivot['Year'] == 2004]
election2008 = election_pivot[election_pivot['Year'] == 2008]
election2012 = election_pivot[election_pivot['Year'] == 2012]
election2016 = election_pivot[election_pivot['Year'] == 2016]
election2020 = election_pivot[election_pivot['Year'] == 2020]

# %%
election2016
# Out:
#        Year    State      County  Democrat Votes  Democrat Percentage  \
# 12455  2016  Alabama     Autauga          5936.0                23.77
# 12456  2016  Alabama     Baldwin         18458.0                19.39
# 12457  2016  Alabama     Barbour          4871.0                46.53
# 12458  2016  Alabama        Bibb          1874.0                21.25
# 12459  2016  Alabama      Blount          2156.0                 8.43
# ...     ...      ...         ...             ...                  ...
# 15564  2016  Wyoming  Sweetwater          3231.0                18.86
# 15565  2016  Wyoming       Teton          7314.0                57.92
# 15566  2016  Wyoming       Uinta          1202.0                14.19
# 15567  2016  Wyoming    Washakie           532.0                13.95
# 15568  2016  Wyoming      Weston           299.0                 8.48
#
#        Republican Votes  Republican Percentage  Libertarian Votes  \
# 12455           18172.0                  72.77                0.0
# 12456           72883.0                  76.55                0.0
# 12457            5454.0                  52.10                0.0
# 12458            6738.0                  76.40                0.0
# 12459           22859.0                  89.33                0.0
# ...                 ...                    ...                ...
# 15564           12154.0                  70.95                0.0
# 15565            3921.0                  31.05                0.0
# 15566            6154.0                  72.66                0.0
# 15567            2911.0                  76.32                0.0
# 15568            3033.0                  86.02                0.0
#
#        Libertarian Percentage  Green Votes  Green Percentage  Other Votes  \
# 12455                     0.0          0.0               0.0        865.0
# 12456                     0.0          0.0               0.0       3874.0
# 12457                     0.0          0.0               0.0        144.0
# 12458                     0.0          0.0               0.0        207.0
# 12459                     0.0          0.0               0.0        573.0
# ...                       ...          ...               ...          ...
# 15564                     0.0          0.0               0.0       1745.0
# 15565                     0.0          0.0               0.0       1392.0
# 15566                     0.0          0.0               0.0       1114.0
# 15567                     0.0          0.0               0.0        371.0
# 15568                     0.0          0.0               0.0        194.0
#
#        Other Percentage  D-R margin  Two party vote share  Total
# 12455              3.46      -49.00                 96.54  24973
# 12456              4.07      -57.16                 95.94  95215
# 12457              1.38       -5.57                 98.63  10469
# 12458              2.35      -55.15                 97.65   8819
# 12459              2.24      -80.90                 97.76  25588
# ...                 ...         ...                   ...    ...
# 15564             10.19      -52.09                 89.81  17130
# 15565             11.02       26.87                 88.97  12627
# 15566             13.15      -58.47                 86.85   8470
# 15567              9.73      -62.37                 90.27   3814
# 15568              5.50      -77.54                 94.50   3526
#
# [3114 rows x 16 columns]

# %% [markdown]
# # Predict 2000
# Using actual data from 2004 to 2020

# %%
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import median_absolute_error
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
# Select relevant columns
target = 'Democrat Percentage'
features = [col for col in election_pivot.columns if col not in ['Year', 'State', 'County', target]]

# %%
# Split data into train (2004-2020) and test (2020)
train_data_rfr = election_pivot[(election_pivot['Year'] >= 2004) & (election_pivot['Year'] <= 2020)]
test_data_rfr = election_pivot[election_pivot['Year'] == 2000]

# %%
# Prepare X (features) and y (target)
X_train_rfr, y_train_rfr = train_data_rfr[features], train_data_rfr[target]
X_test_rfr, y_test_rfr = test_data_rfr[features], test_data_rfr[target]

# %%
# Train the model
rfr = RandomForestRegressor(random_state=42)
rfr.fit(X_train_rfr, y_train_rfr)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Predict for 2000
y_pred_rfr = rfr.predict(X_test_rfr)

# %%
# Convert the predictions to a DataFrame
y_pred_rfr_df = pd.DataFrame(y_pred_rfr, index=test_data_rfr.index, columns=['Predicted Democrat Percentage'])

# Include 'State' and 'County' columns in the comparison
comparison_df = pd.concat([test_data_rfr[['State', 'County', target]], y_pred_rfr_df], axis=1)

# Rename columns for clarity
comparison_df.columns = ['State', 'County', 'Actual Democrat Percentage', 'Predicted Democrat Percentage']

# Calculate the difference
comparison_df['Difference'] = comparison_df['Predicted Democrat Percentage'] - comparison_df['Actual Democrat Percentage']

# Display the comparison
comparison_df['Absolute Difference'] = comparison_df['Difference'].abs()

# %%
comparison_df
# Out:
#         State      County  Actual Democrat Percentage  \
# 0     Alabama     Autauga                       28.72
# 1     Alabama     Baldwin                       24.78
# 2     Alabama     Barbour                       49.91
# 3     Alabama        Bibb                       38.16
# 4     Alabama      Blount                       27.69
# ...       ...         ...                         ...
# 3108  Wyoming  Sweetwater                       35.19
# 3109  Wyoming       Teton                       38.53
# 3110  Wyoming       Uinta                       22.24
# 3111  Wyoming    Washakie                       19.90
# 3112  Wyoming      Weston                       14.67
#
#       Predicted Democrat Percentage  Difference  Absolute Difference
# 0                           29.5213      0.8013               0.8013
# 1                           26.5406      1.7606               1.7606
# 2                           49.5288     -0.3812               0.3812
# 3                           38.8275      0.6675               0.6675
# 4                           28.5379      0.8479               0.8479
# ...                             ...         ...                  ...
# 3108                        36.6974      1.5074               1.5074
# 3109                        45.6593      7.1293               7.1293
# 3110                        23.3208      1.0808               1.0808
# 3111                        20.4699      0.5699               0.5699
# 3112                        15.4936      0.8236               0.8236
#
# [3113 rows x 6 columns]

# %%
comparison_df.nlargest(10, 'Absolute Difference')
# Out:
#               State       County  Actual Democrat Percentage  \
# 1797       Missouri  Kansas City                        0.00
# 2535          Texas       Collin                       24.45
# 271        Colorado   San Miguel                       49.09
# 2756           Utah        Grand                       32.04
# 1598        Montana     Missoula                       37.02
# 179      California    Mendocino                       48.34
# 1193  Massachusetts    Hampshire                       56.16
# 1191  Massachusetts     Franklin                       53.78
# 270        Colorado     San Juan                       34.17
# 2865       Virginia     Richmond                      101.29
#
#       Predicted Democrat Percentage  Difference  Absolute Difference
# 1797                        92.5312     92.5312              92.5312
# 2535                        48.1890     23.7390              23.7390
# 271                         65.9798     16.8898              16.8898
# 2756                        47.1052     15.0652              15.0652
# 1598                        51.8456     14.8256              14.8256
# 179                         62.9008     14.5608              14.5608
# 1193                        70.1932     14.0332              14.0332
# 1191                        67.3776     13.5976              13.5976
# 270                         47.3492     13.1792              13.1792
# 2865                        88.1679    -13.1221              13.1221

# %% [markdown]
# # Predict 2020
# Using actual data from 2000 to 2016

# %%
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import median_absolute_error
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
# Select relevant columns
target = 'Democrat Percentage'
features = [col for col in election_pivot.columns if col not in ['Year', 'State', 'County', target]]

# %%
# Split data into train (2000-2016) and test (2020)
train_data_rfr = election_pivot[(election_pivot['Year'] >= 2000) & (election_pivot['Year'] <= 2016)]
test_data_rfr = election_pivot[election_pivot['Year'] == 2020]

# %%
# Prepare X (features) and y (target)
X_train_rfr, y_train_rfr = train_data_rfr[features], train_data_rfr[target]
X_test_rfr, y_test_rfr = test_data_rfr[features], test_data_rfr[target]

# %%
# Train the model
rfr = RandomForestRegressor(random_state=42)
rfr.fit(X_train_rfr, y_train_rfr)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Predict for 2020
y_pred_rfr = rfr.predict(X_test_rfr)

# %%
# Convert the predictions to a DataFrame
y_pred_rfr_df = pd.DataFrame(y_pred_rfr, index=test_data_rfr.index, columns=['Predicted Democrat Percentage'])

# Include 'State' and 'County' columns in the comparison
comparison_df = pd.concat([test_data_rfr[['State', 'County', target]], y_pred_rfr_df], axis=1)

# Rename columns for clarity
comparison_df.columns = ['State', 'County', 'Actual Democrat Percentage', 'Predicted Democrat Percentage']

# Calculate the difference
comparison_df['Difference'] = comparison_df['Predicted Democrat Percentage'] - comparison_df['Actual Democrat Percentage']

# Display the comparison
comparison_df['Absolute Difference'] = comparison_df['Difference'].abs()

# %%
comparison_df.nlargest(10, 'Absolute Difference')
# Out:
#               State         County  Actual Democrat Percentage  \
# 17746         Texas        Roberts                        3.09
# 15957       Georgia        Clayton                       84.99
# 18280  South Dakota  Oglala Lakota                       88.41
# 15970       Georgia         Dekalb                       83.12
# 17482  Pennsylvania   Philadelphia                       81.44
# 17566         Texas         Borden                        3.85
# 18284  South Dakota           Todd                       77.31
# 17719         Texas     Montgomery                       27.39
# 16293       Indiana           Ohio                       21.72
# 18626     Wisconsin      Menominee                       81.95
#
#        Predicted Democrat Percentage  Difference  Absolute Difference
# 17746                        84.1834     81.0934              81.0934
# 15957                        67.0155    -17.9745              17.9745
# 18280                        70.4653    -17.9447              17.9447
# 15970                        65.6127    -17.5073              17.5073
# 17482                        64.1513    -17.2887              17.2887
# 17566                        17.3764     13.5264              13.5264
# 18284                        64.4453    -12.8647              12.8647
# 17719                        39.4275     12.0375              12.0375
# 16293                        33.0060     11.2860              11.2860
# 18626                        76.7956     -5.1544               5.1544

# %%
comparison_df.nsmallest(10, 'Absolute Difference')
# Out:
#            State     County  Actual Democrat Percentage  \
# 15901    Florida     Martin                       37.37
# 15587    Alabama      Coosa                       32.78
# 17692      Texas     Lavaca                       13.07
# 15616    Alabama   Marshall                       14.99
# 15605    Alabama  Jefferson                       55.76
# 15575    Alabama     Butler                       41.79
# 18292  Tennessee    Bedford                       23.33
# 15589    Alabama   Crenshaw                       25.69
# 18293  Tennessee     Benton                       21.06
# 17612      Texas    Dickens                       13.16
#
#        Predicted Democrat Percentage  Difference  Absolute Difference
# 15901                        37.3710      0.0010               0.0010
# 15587                        32.7786     -0.0014               0.0014
# 17692                        13.0716      0.0016               0.0016
# 15616                        14.9917      0.0017               0.0017
# 15605                        55.7618      0.0018               0.0018
# 15575                        41.7930      0.0030               0.0030
# 18292                        23.3344      0.0044               0.0044
# 15589                        25.6847     -0.0053               0.0053
# 18293                        21.0545     -0.0055               0.0055
# 17612                        13.1543     -0.0057               0.0057

# %%
comparison_df.nlargest(10, 'Difference')
# Out:
#               State      County  Actual Democrat Percentage  \
# 17746         Texas     Roberts                        3.09
# 17566         Texas      Borden                        3.85
# 17719         Texas  Montgomery                       27.39
# 16293       Indiana        Ohio                       21.72
# 17684         Texas        King                        5.03
# 16122         Idaho     Madison                       15.58
# 18264  South Dakota    Lawrence                       32.81
# 18270  South Dakota       Meade                       24.03
# 17388  North Dakota      Steele                       36.03
# 18410          Utah        Utah                       26.75
#
#        Predicted Democrat Percentage  Difference  Absolute Difference
# 17746                        84.1834     81.0934              81.0934
# 17566                        17.3764     13.5264              13.5264
# 17719                        39.4275     12.0375              12.0375
# 16293                        33.0060     11.2860              11.2860
# 17684                        10.0882      5.0582               5.0582
# 16122                        19.3808      3.8008               3.8008
# 18264                        36.5429      3.7329               3.7329
# 18270                        27.7356      3.7056               3.7056
# 17388                        39.6500      3.6200               3.6200
# 18410                        30.1864      3.4364               3.4364

# %%
comparison_df.nsmallest(10, 'Difference')
# Out:
#               State         County  Actual Democrat Percentage  \
# 17497  Pennsylvania   Philadelphia                       81.44
# 15972       Georgia        Clayton                       84.99
# 15985       Georgia         Dekalb                       83.12
# 18296  South Dakota  Oglala Lakota                       88.41
# 16011       Georgia        Hancock                       71.66
# 16063       Georgia       Rockdale                       69.92
# 15988       Georgia      Dougherty                       69.60
# 16001       Georgia         Fulton                       72.65
# 15872      Delaware     New Castle                       67.81
# 18300  South Dakota           Todd                       77.31
#
#        Predicted Democrat Percentage  Difference
# 17497                        77.0012     -4.4388
# 15972                        80.7399     -4.2501
# 15985                        79.0401     -4.0799
# 18296                        84.7742     -3.6358
# 16011                        68.1065     -3.5535
# 16063                        66.8806     -3.0394
# 15988                        66.5625     -3.0375
# 16001                        69.6637     -2.9863
# 15872                        65.1215     -2.6885
# 18300                        74.6276     -2.6824

# %%
(comparison_df['Difference'] > 0).value_counts()
# Out:
# Difference
# True     2968
# False     146
# Name: count, dtype: int64

# %% [markdown]
# # Take averages and aggregates by state

# %% [markdown]
# For each state, find the average absolute error by each county.

# %% [markdown]
# Make a spikeplot similar to my climate project.

# %%
# Prepare X (features) and y (target)
X_train_rfr, y_train_rfr = train_data_rfr[features], train_data_rfr[target]
X_test_rfr, y_test_rfr = test_data_rfr[features], test_data_rfr[target]

# %%
rfr_params = {
    'n_estimators': [50, 100, 200, 300],  # Number of trees
    'max_depth': [None, 10, 20, 30],  # Maximum depth of trees
    'min_samples_split': [2, 5, 10],  # Minimum samples per split
    'min_samples_leaf': [1, 2, 4],  # Minimum samples per leaf
    'max_features': ['sqrt', 'log2']  # Number of features to consider for splits
}

# %%
rfr = RandomForestRegressor(random_state=42)

# %%
rfr_gs = GridSearchCV(estimator=rfr, param_grid=rfr_params, 
                           cv=5, scoring='neg_mean_squared_error', 
                           n_jobs=-1, verbose=1)

# %%
# %%time
# Fit on training data
rfr_gs.fit(X_train_rfr, y_train_rfr)

# %%
import pandas as pd

# Assuming your DataFrame is named df
df_pivoted_votes = elections.pivot_table(index='County', columns=['Year', 'Party'], values='Votes', aggfunc='sum')
df_pivoted_percentage = elections.pivot_table(index='County', columns=['Year', 'Party'], values='Percentage', aggfunc='sum')

# Flatten the multi-level column index
df_pivoted_votes.columns = [f"{year} {party} Votes" for year, party in df_pivoted_votes.columns]
df_pivoted_percentage.columns = [f"{year} {party} Percentage" for year, party in df_pivoted_percentage.columns]

# Combine the two DataFrames
df_final = pd.concat([df_pivoted_votes, df_pivoted_percentage], axis=1)

# Sort by County if needed
df_final = df_final.sort_index(axis=0)

# Display the final result
df_final
# Out:
#                            2000 Democrat Votes  2000 Green Votes  \
# County
# Abbeville, South Carolina               3766.0              66.0
# Acadia, Louisiana                       8892.0             227.0
# Accomack, Virginia                      5092.0             220.0
# Ada, Idaho                             40650.0            4846.0
# Adair, Iowa                             1753.0              66.0
# ...                                        ...               ...
# Yuma, Arizona                          12055.0             495.0
# Yuma, Colorado                          1082.0              60.0
# Zapata, Texas                           1638.0              11.0
# Zavala, Texas                           2616.0              14.0
# Ziebach, South Dakota                    314.0               0.0
#
#                            2000 Other Votes  2000 Republican Votes  \
# County
# Abbeville, South Carolina              92.0                 4450.0
# Acadia, Louisiana                     305.0                13814.0
# Accomack, Virginia                    261.0                 6352.0
# Ada, Idaho                           2939.0                75050.0
# Adair, Iowa                            29.0                 2275.0
# ...                                     ...                    ...
# Yuma, Arizona                         394.0                15708.0
# Yuma, Colorado                         60.0                 3156.0
# Zapata, Texas                          14.0                  953.0
# Zavala, Texas                          10.0                  751.0
# Ziebach, South Dakota                  23.0                  384.0
#
#                            2004 Democrat Votes  2004 Other Votes  \
# County
# Abbeville, South Carolina               4389.0             100.0
# Acadia, Louisiana                       8937.0             210.0
# Accomack, Virginia                      5518.0             112.0
# Ada, Idaho                             58523.0            1838.0
# Adair, Iowa                             1844.0              32.0
# ...                                        ...               ...
# Yuma, Arizona                          16032.0             249.0
# Yuma, Colorado                          1064.0              39.0
# Zapata, Texas                           1662.0               8.0
# Zavala, Texas                           2332.0               9.0
# Ziebach, South Dakota                    641.0              28.0
#
#                            2004 Republican Votes  2008 Democrat Votes  \
# County
# Abbeville, South Carolina                 5436.0               4593.0
# Acadia, Louisiana                        16083.0               7028.0
# Accomack, Virginia                        7726.0               7607.0
# Ada, Idaho                               94641.0              82236.0
# Adair, Iowa                               2402.0               1924.0
# ...                                          ...                  ...
# Yuma, Arizona                            22184.0              18559.0
# Yuma, Colorado                            3456.0               1117.0
# Zapata, Texas                             1228.0               1939.0
# Zavala, Texas                              777.0               3263.0
# Ziebach, South Dakota                      447.0                554.0
#
#                            2008 Other Votes  2008 Republican Votes  ...  \
# County                                                              ...
# Abbeville, South Carolina             144.0                 6264.0  ...
# Acadia, Louisiana                     454.0                19228.0  ...
# Accomack, Virginia                    183.0                 7833.0  ...
# Ada, Idaho                           3838.0                93328.0  ...
# Adair, Iowa                            69.0                 2060.0  ...
# ...                                     ...                    ...  ...
# Yuma, Arizona                         479.0                24577.0  ...
# Yuma, Colorado                         80.0                 3286.0  ...
# Zapata, Texas                           8.0                  919.0  ...
# Zavala, Texas                          17.0                  596.0  ...
# Ziebach, South Dakota                  16.0                  312.0  ...
#
#                            2012 Other Percentage  2012 Republican Percentage  \
# County
# Abbeville, South Carolina                   1.38                       56.05
# Acadia, Louisiana                           1.28                       74.27
# Accomack, Virginia                          1.14                       51.17
# Ada, Idaho                                  3.24                       54.03
# Adair, Iowa                                 2.30                       52.90
# ...                                          ...                         ...
# Yuma, Arizona                               1.29                       55.66
# Yuma, Colorado                              2.18                       76.25
# Zapata, Texas                               0.54                       28.14
# Zavala, Texas                               1.01                       15.71
# Ziebach, South Dakota                       1.05                       41.26
#
#                            2016 Democrat Percentage  2016 Other Percentage  \
# County
# Abbeville, South Carolina                     34.72                   2.52
# Acadia, Louisiana                             20.58                   2.15
# Accomack, Virginia                            42.61                   3.13
# Ada, Idaho                                    38.68                  13.41
# Adair, Iowa                                   29.73                   5.69
# ...                                             ...                    ...
# Yuma, Arizona                                 46.42                   6.11
# Yuma, Colorado                                15.15                   4.49
# Zapata, Texas                                 65.66                   1.59
# Zavala, Texas                                 77.62                   1.94
# Ziebach, South Dakota                         46.02                   6.00
#
#                            2016 Republican Percentage  \
# County
# Abbeville, South Carolina                       62.77
# Acadia, Louisiana                               77.26
# Accomack, Virginia                              54.26
# Ada, Idaho                                      47.91
# Adair, Iowa                                     64.58
# ...                                               ...
# Yuma, Arizona                                   47.47
# Yuma, Colorado                                  80.36
# Zapata, Texas                                   32.75
# Zavala, Texas                                   20.44
# Ziebach, South Dakota                           47.98
#
#                            2020 Democrat Percentage  2020 Green Percentage  \
# County
# Abbeville, South Carolina                     32.98                   0.18
# Acadia, Louisiana                             19.15                    NaN
# Accomack, Virginia                            44.68                    NaN
# Ada, Idaho                                    46.47                    NaN
# Adair, Iowa                                   28.68                   0.09
# ...                                             ...                    ...
# Yuma, Arizona                                 46.09                   0.00
# Yuma, Colorado                                15.76                   0.04
# Zapata, Texas                                 47.13                   0.10
# Zavala, Texas                                 65.40                   0.27
# Ziebach, South Dakota                         53.09                    NaN
#
#                            2020 Libertarian Percentage  2020 Other Percentage  \
# County
# Abbeville, South Carolina                         0.71                   0.05
# Acadia, Louisiana                                 0.85                   0.51
# Accomack, Virginia                                1.11                   0.14
# Ada, Idaho                                        2.05                   1.10
# Adair, Iowa                                       0.84                   0.43
# ...                                                ...                    ...
# Yuma, Arizona                                     1.63                   0.00
# Yuma, Colorado                                    1.04                   0.70
# Zapata, Texas                                     0.28                   0.00
# Zavala, Texas                                     0.30                   0.00
# Ziebach, South Dakota                             2.32                    NaN
#
#                            2020 Republican Percentage
# County
# Abbeville, South Carolina                       66.06
# Acadia, Louisiana                               79.49
# Accomack, Virginia                              54.07
# Ada, Idaho                                      50.39
# Adair, Iowa                                     69.96
# ...                                               ...
# Yuma, Arizona                                   52.28
# Yuma, Colorado                                  82.45
# Zapata, Texas                                   52.48
# Zavala, Texas                                   34.03
# Ziebach, South Dakota                           44.59
#
# [3193 rows x 42 columns]

# %%
import pandas as pd

# Assuming your dataframe is called 'election_data'
pivoted_df = elections.pivot_table(index=['county_name'], columns=['year', 'party'], values='candidatevotes', aggfunc='sum')

# Flatten the MultiIndex columns (if necessary)
pivoted_df.columns = [f'{party}_{year}' for year, party in pivoted_df.columns]

# Reset the index if you want 'County' as a column
pivoted_df.reset_index(inplace=True)

# Display the reformatted dataframe
pivoted_df
# Out:
#      county_name  DEMOCRAT_2000  GREEN_2000  OTHER_2000  REPUBLICAN_2000  \
# 0      ABBEVILLE         3766.0        66.0        92.0           4450.0
# 1         ACADIA         8892.0       227.0       305.0          13814.0
# 2       ACCOMACK         5092.0       220.0       261.0           6352.0
# 3            ADA        40650.0      4846.0      2939.0          75050.0
# 4          ADAIR         9994.0       415.0       283.0          17288.0
# ...          ...            ...         ...         ...              ...
# 1887        YUBA         5546.0       507.0       236.0           9838.0
# 1888        YUMA        13137.0       555.0       454.0          18864.0
# 1889      ZAPATA         1638.0        11.0        14.0            953.0
# 1890      ZAVALA         2616.0        14.0        10.0            751.0
# 1891     ZIEBACH          314.0         0.0        23.0            384.0
#
#       DEMOCRAT_2004  OTHER_2004  REPUBLICAN_2004  DEMOCRAT_2008  OTHER_2008  \
# 0            4389.0       100.0           5436.0         4593.0       144.0
# 1            8937.0       210.0          16083.0         7028.0       454.0
# 2            5518.0       112.0           7726.0         7607.0       183.0
# 3           58523.0      1838.0          94641.0        82236.0      3838.0
# 4           11108.0       186.0          19368.0        11379.0       432.0
# ...             ...         ...              ...            ...         ...
# 1887         5687.0       257.0          12076.0         8866.0       528.0
# 1888        17096.0       288.0          25640.0        19676.0       559.0
# 1889         1662.0         8.0           1228.0         1939.0         8.0
# 1890         2332.0         9.0            777.0         3263.0        17.0
# 1891          641.0        28.0            447.0          554.0        16.0
#
#       ...  OTHER_2012  REPUBLICAN_2012  DEMOCRAT_2016  OTHER_2016  \
# 0     ...       147.0           5981.0         3741.0       271.0
# 1     ...       344.0          19931.0         5638.0       589.0
# 2     ...       183.0           8213.0         6740.0       495.0
# 3     ...      5855.0          97554.0        75677.0     26240.0
# 4     ...       447.0          17987.0         7338.0      1530.0
# ...   ...         ...              ...            ...         ...
# 1887  ...       714.0          11275.0         7910.0      1918.0
# 1888  ...       642.0          26842.0        25331.0      3455.0
# 1889  ...        19.0            997.0         2063.0        50.0
# 1890  ...        37.0            574.0         2636.0        66.0
# 1891  ...         8.0            314.0          353.0        46.0
#
#       REPUBLICAN_2016  DEMOCRAT_2020  GREEN_2020  LIBERTARIAN_2020  \
# 0              6763.0         4101.0        23.0              88.0
# 1             21162.0         5443.0         NaN             241.0
# 2              8583.0         7578.0         NaN             188.0
# 3             93752.0       120539.0         NaN            5310.0
# 4             19915.0         7687.0        47.0             314.0
# ...               ...            ...         ...               ...
# 1887          13170.0        11230.0       124.0             510.0
# 1888          29015.0        32995.0         2.0            1189.0
# 1889           1029.0         1826.0         4.0              11.0
# 1890            694.0         2864.0        12.0              13.0
# 1891            368.0          481.0         NaN              21.0
#
#       OTHER_2020  REPUBLICAN_2020
# 0            6.0           8215.0
# 1          145.0          22596.0
# 2           24.0           9172.0
# 3         2841.0         130699.0
# 4          140.0          22196.0
# ...          ...              ...
# 1887       256.0          17676.0
# 1888        35.0          40641.0
# 1889         0.0           2033.0
# 1890         0.0           1490.0
# 1891         NaN            404.0
#
# [1892 rows x 22 columns]
